# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulpatilrdp-code/Assignments/blob/main/MTA_QA1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QA1__Perform Operations Using Data Types and Operators

# %%
#Q1

# %%
x=8
y=10

# %%
result=x//3*3/2+y%2**2

# %%
result
# Out:
# 5.0

# %%
#Q2

# %%
start=input('How old were you at the time of joining')
end=input('How old are you today')
print('Congratulations on '+str(int(end)-int(start))+' Years of service')
# Out:
# How old were you at the time of joining22
# How old are you today28
# Congratulations on 6 Years of service

# %%
#Q3  -We dont want cat word

# %%
x='ACROTE'
y='APPLE'
z='TOMATO'

# %%
print(x[2],y[1],z[1])
# Out:
# R P O

# %%
#Q4

# %%
x='Durga'
y='Durga'

# %%
x is y
# Out:
# True

# %%
x<y
# Out:
# False

# %%
x!=y
# Out:
# False

# %%
#Q5

# %%
#code 1
a1='10'
b1=3
c1=a1*b1

#code2

a2=10
b2=3
c2=a2/b2

#code3
a3=2.6
b3=1
c3=a3/b3

# %%
c1,c2,c3
# Out:
# ('101010', 3.3333333333333335, 2.6)

# %%
type(c1),type(c2),type(c3)
# Out:
# (str, float, float)

# %%
#Q6 which will give same result

# %%
13//4, 11/3, 3**1, 23%5
# Out:
# (3, 3.6666666666666665, 3, 3)

# %%
#Q7

# %%
n1=[10,20,30,40,50]
n2=[10,20,30,40,50]

# %%
print(n1 is n2)
print(n1==n2)
# Out:
# False
# True

# %%
#Q8 ans must be zero

# %%
a=1
b=3
c=5
d=7
result1=a**d-1
result2=a%b-1

# %%
result1,result2
# Out:
# (0, 0)

# %%
#Q9

# %%
del list    #here "del list" is used as list was over written and was giving error "list object is not callable"
s='AB CD'
lst=list(s)
lst.append('EF')
print(lst)
# Out:
# ['A', 'B', ' ', 'C', 'D', 'EF']

# %%
#Q10

# %%
a=5
b=10
c=2
d=True

# %%
x=a+b*c
y=a+b/d

if(x>y):
  print('Valid')
else:
  print('Invalid')
# Out:
# Valid

# %%
#Q11

# %%
x=input("Enter First Number")
y=input("Enter Second Number")
print('The Result:' + str(int(x)+int(y)))
# Out:
# Enter First Number2
# Enter Second Number4
# The Result:6

# %%
#Q12

# %%
a=20
b=15
c=10
d=5
z=a-b*c+d

# %%
z
# Out:
# -125

# %%
#Q13

# %%
weight=62.4
zip='80098'
value=+23E4

# %%
type(weight),type(zip),type(value)
# Out:
# (float, str, float)

# %%
#Q14

# %%
a=10+20
b='10'+'20'
c='10'*3

# %%
a,b,c
# Out:
# (30, '1020', '101010')

# %%
type(a),type(b),type(c)
# Out:
# (int, str, str)

# %%
#Q15

# %%
c=bool()    #for Empty string, empty list, empty tuple, empty set, empty dict this argument returns false.

# %%
c
# Out:
# False

# %%
#Q16

# %%
result=(2*(3+4)**2-(3**3)*3)    # 1-Parenthesis, 2-Exponent, 3-(Mul,Div,Moddulo,Floor div), 4-Add,Sub

# %%
result
# Out:
# 17

# %%
#Q17

# %%
a=2
a += 1
a**=2

# %%
a
# Out:
# 9

# %%
#Q18

# %%
a=bool(0)   #which will give true
b=bool(3)
c=bool(0.5)
d=bool(0.0)

# %%
a,b,c,d
# Out:
# (False, True, True, False)

# %%
#Q19

# %%
a=21
b=6

# %%
print(a/b)
print(a//b)
print(a%b)
# Out:
# 3.5
# 3
# 3

# %%
#Q20 500 employees list we want last 3 from it

# %%
# employees[-3:0]    ,employees[497:500],   employees[497:]

# %%
#Q21

# %%
subjects=['java','python','sap']
more_subjects=['java','python','sap']
extra_subjects=more_subjects

# %%
print(extra_subjects is more_subjects)    #is operator for reference comparision
print(subjects==more_subjects)            #==  for content comparision
# Out:
# True
# True

# %%
#Q22---- 500 employees list,in which case we will get index error.
        #employees[0:501], employees[1:1000], employees[-10:10]    #all are right.

# %%
#Q23

# %%
numbers=[10,20,30,40,50]
alphabets=['a','b','c','d','e']
print(numbers is alphabets)
print(numbers==alphabets)
numbers=alphabets
print(numbers is alphabets)
print(numbers==alphabets)
# Out:
# False
# False
# True
# True

# %%
#Q24

# %%
a=0
minor=False
name='Durga'

# %%
type(0), type(minor), type('Durga')
# Out:
# (int, bool, str)

# %%
#Q25 which will give max value

# %%
a=8//3*4
b=8%3*4
c=8/3*4
d=8-3*4

# %%
a,b,c,d
# Out:
# (8, 8, 10.666666666666666, -4)

# %%
#Q26

# %%
s='Python is easy'
s1=s[6:-4]
s2=s1.strip()
print(len(s2))
# Out:
# 2

# %%
#Q27  -From 600 employees exclude lasst 3
      #employees[:-3],  emloyees[0:-3]

# %%
#Q28

# %%
list=['Apple','Banana','Carrot','Mango']  #access mango

# %%
list[-1]
# Out:
# 'Mango'

# %%
list[3]
# Out:
# 'Mango'

# %%
#Q29 print boy,cat,dog

# %%
l=['Apple','Boy','Cat','Dog']
for x in l:
  if len(x)==3:
    print(x)
# Out:
# Boy
# Cat
# Dog

# %%
l=['Apple','Boy','Cat','Dog']
l1=l[1:]
for x in l1:
  print(x)
# Out:
# Boy
# Cat
# Dog

# %%
#Q30

# %%
a=15
b=5
print(a/b)
# Out:
# 3.0

# %%
#Q31 500 employess which will give index error--employees[500] ,no error-employees[0],employees[-1]

# %%
#Q32

# %%
a=1
b=2
c=4
d=6
#result = 4

# %%
(a+b)//d-c
# Out:
# -4

# %%
#Q33

# %%
s='Python is easy'
s1=s[-7:]
s2=s[-4:]
print(s1+s2)
# Out:
# is easyeasy

# %%
#Q34 Operator precedence order
#1-Parenthesis, 2-Exponents, 3-Unary Positive,negative,N ot. 4-Mul,Div. 5-Add,sub. 6-And

# %%
#Q35 ----b=(-a)**2

# %%
#Q36

# %%
result=8//6%5+2**3-2
print(result)
# Out:
# 7

# %%
#Q37

# %%
a=3
b=5
a+=2**3
a-=b//2//3
print(a)
# Out:
# 11

# %%
#38

# %%
a=bool([])
b=bool(())
c=bool(range(0))
d=bool({})
e=bool(set())

# %%
a,b,c,d,e
# Out:
# (False, False, False, False, False)

# %%
#39-- Output=10

# %%
numbers=[10,20,30,40]
x=0

# %%
for i in (30,40,50):
  if i in numbers:
    x=x+5
print(x)
# Out:
# 10

# %%
for i in (30,40,50):
  if i not in numbers:
    x=x+10
print(x)
# Out:
# 10

# %%
#Q40

# %%
n1=[10,20,30,40,50]
n2=[10,20,30,40,50]
print(n1 is n2)
print(n1==n2)
n1=n2
print(n1 is n2)
print(n1==n2)
# Out:
# False
# True
# True
# True
