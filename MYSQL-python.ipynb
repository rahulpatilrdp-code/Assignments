# %%
pwd
# Out:
# 'C:\\Users\\rahul'

# %%
##Connectivity between Python & MySQL

# %%
import mysql.connector as connection

# %%
mydb=connection.connect(host='localhost',user='root',password='root')

# %%
type(mydb)
# Out:
# mysql.connector.connection_cext.CMySQLConnection

# %%
q1="show databases"

# %%
q1
# Out:
# 'show databases'

# %%
cursor=mydb.cursor()

# %%
cursor.execute(q1)

# %%
cursor.fetchall()
# Out:
# [('b111',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sakila',),
#  ('sys',),
#  ('world',)]

# %%
import mysql.connector as connection

try:
    mydb=connection.connect(host="localhost",user="root",password="root")
    q1="show databases"
    cursor=mydb.cursor()
    cursor.execute(q1)
    print(cursor.fetchall())
except:
    mydb.close()
    print(str(e))
# Out:
# [('b111',), ('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('world',)]

# %%
mydb.is_connected()
# Out:
# True

# %%
import mysql.connector as connection

try:
    mydb=connection.connect(host="localhost",user="root",password="root")
    print(mydb.is_connected())
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True

# %%
##create database

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root")
    print(mydb.is_connected())

    q2="create database 25jan;"
    cursor=mydb.cursor()
    cursor.execute(q2)
    print("Database is created successfully")
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
# Database is created successfully

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root")
    q1="show databases"
    cursor=mydb.cursor()
    cursor.execute(q1)
    print(cursor.fetchall())
except:
    mydb.close()
    print(str(e))
# Out:
# [('25jan',), ('b111',), ('information_schema',), ('mysql',), ('performance_schema',), ('sakila',), ('sys',), ('world',)]

# %%
##connect to database 25jan

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="25jan")
    print(mydb.is_connected())

    q3="create table student(sid int(10) auto_increment primary key,fname varchar(20),"\
    "Lname varchar(30),RegDate date,class varchar(5),section varchar(5));"
    cursor=mydb.cursor()
    cursor.execute(q3)
    print("Table is created successfully")
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
# Table is created successfully

# %%
#fetch all data from emp,dept

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="b111")
    print(mydb.is_connected())

    q4="select * from emp;"
    cursor=mydb.cursor()
    cursor.execute(q4)
    print(cursor.fetchall())
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
# ...

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="b111")
    print(mydb.is_connected())

    q4="select * from emp;"
    cursor=mydb.cursor()
    cursor.execute(q4)
    for v in cursor.fetchall():
        print(v)
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
# (7369, 'SMITH', 'CLERK', 7902, datetime.date(1980, 12, 17), 800, None, 20)
# (7499, 'ALLEN', 'SALESMAN', 7698, datetime.date(1981, 2, 20), 1600, 300, 30)
# (7521, 'WARD', 'SALESMAN', 7698, datetime.date(1981, 2, 22), 1250, 500, 30)
# (7566, 'JONES', 'MANAGER', 7839, datetime.date(1981, 4, 2), 2975, None, 20)
# (7654, 'MARTIN', 'SALESMAN', 7698, datetime.date(1981, 9, 22), 1250, 1400, 30)
# (7698, 'BLAKE', 'MANAGER', 7839, datetime.date(1981, 5, 1), 2850, None, 30)
# (7782, 'CLARK', 'MANAGER', 7839, datetime.date(1981, 6, 9), 2450, None, 10)
# (7788, 'SCOTT', 'ANALYST', 7566, datetime.date(1987, 9, 23), 3000, None, 20)
# (7839, 'KING', 'PRESIDENT', None, datetime.date(1981, 11, 19), 5000, None, 10)
# (7844, 'TURNER', 'SALESMAN', 7698, datetime.date(1981, 9, 8), 1500, 0, 30)
# (7876, 'ADAMS', 'CLERK', 7788, datetime.date(1987, 8, 24), 1100, None, 20)
# (7900, 'JAMES', 'CLERK', 7698, datetime.date(1981, 12, 3), 950, None, 30)
# ...

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="b111")
    print(mydb.is_connected())

    q4="select * from dept;"
    cursor=mydb.cursor()
    cursor.execute(q4)
    for v in cursor.fetchall():
        print(v)
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
# (10, 'ACCOUNTING', 'NEW YORK')
# (20, 'RESEARCH', 'DALLAS')
# (30, 'SALES', 'CHICAGO')
# (40, 'OPERATIONS', 'BOSTON')

# %%
##insert data in student file

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="25jan")
    print(mydb.is_connected())

    q6="insert into student values(101,'sachin','patil','2025-12-12','Ten','A');"
    cursor=mydb.cursor()
    cursor.execute(q6)
    mydb.commit()
    mydb.close()
except:
    mydb.close()
    print(str(e))     #i already run this command that's why showing error.
# Out:
# True
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\mysql\connector\connection_cext.py:772, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     770     self._local_infile_filenames = None
# --> 772     self._cmysql.query(
#     773         query,
#     774         raw=raw,
#     775         buffered=buffered,
#     776         raw_as_string=raw_as_string,
#     777         query_attrs=self.query_attrs,
#     778     )
#     779 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '101' for key 'student.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[37], line 7
#       6 cursor=mydb.cursor()
# ----> 7 cursor.execute(q6)
#       8 mydb.commit()
#
# ...

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="25jan")
    print(mydb.is_connected())

    q6="insert into student values(102,'kunal','ne','2022-10-12','Nine','B');"
    cursor=mydb.cursor()
    cursor.execute(q6)
    mydb.commit()
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True

# %%
try:
    mydb=connection.connect(host="localhost",user="root",password="root",database="25jan")
    print(mydb.is_connected())

    q6="insert into student values(108,'virat','kohli','1999-10-12','four','f');"
    cursor=mydb.cursor()
    cursor.execute(q6)
    mydb.commit()
    mydb.close()
except:
    mydb.close()
    print(str(e))
# Out:
# True
